# %% [markdown]
# * # Basic Informations
# 1. this session is meant to give you overall idea, best practice & tips that will help in writing best clean, optimized & strucutred python code.
# 2. session will cover topics that is expected from an AI Engineer to know before working in any project
#
# ## Below are the topics will be covered in this session.
#     0. static/dynamic typing, variable scope, dir()/help()/isinstance(), attr(), types(int,str,bool,None), basic-DS(list,tuple,set,dict)
#     1. itertools, collections
#     2. Pydantic
#     3. comprehension operation
#     4. decorators, generators, context-manager(using with statement), Exception
#     5. asyncio, Mutlithreading
#     6. OOP(dataclass, staticmethod, classmethod)
#     7. logging, pandas, json, numpy, aiohttp, requests, pymongo(CRUD), elasticsearch(CRUD), ORM, Sqlalchemy, redis , pyTest , Indexing
#     8. Rest API using FastAPI
#     9. debugging code using python debugger(pdb)
#     10. Session (OAuth, SSO , JWT try multiple ways)
#     11. genAI / LLM -> (Prompt Engineering , Working with OpenAI’s GPT-3/4 , API Calls to LLMs, Building Applications with LLMs)
#     12. Git , Github , Mircroservices (Docker (for containerization),Kubernetes (for container orchestration)

# %% [markdown]
# ## static/dynamic typing

# %%
ename_0 = 'Ratan'
ename_1: str = 'Ratan'

print(ename_0)
print(ename_1)
# Out:
# Ratan
# Ratan

# %% [markdown]
# ## types(int,str,bool,None), basic-DS(list,tuple,set,dict)

# %%
# https://realpython.com/python-data-types/
# iter(), next() are built-in functions
iterator1 = iter([1, 2, 3, 4]) # iter() is an iterator operator, [1,2,3,4] is an iterable, iterator1 is iterator object
print(next(iterator1))
# {'a':123,''}
{'a': 123, 'b': ''}
# Out:
# 1
# {'a': 123, 'b': ''}

# %%
def func():
    response = {}
    def inner():
        nonlocal response
        response['a'] = 123
        return response
    return inner

out = func()
if out is None:
    print()
else:
    out.get('msg',None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 13
#      11     print()
#      12 else:
# ---> 13     out.get('msg',None)
#
# AttributeError: 'function' object has no attribute 'get'
